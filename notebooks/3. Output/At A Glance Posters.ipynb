# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)
def percent(x, y):
    return (x/y)*100
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
import pickle
import requests

# %% [markdown]
# # At a Glance Posters
# This notebook organizes the data per each county needed for the "At a Glance" presentation posters. The last update was exported on 8/23/

# %%
#to read in... rb is read bite
with open('api_keys.pkl', 'rb') as keys_file:
        keys_dict_2 = pickle.load(keys_file)
#create a variable that contains your api key
census_key = keys_dict_2['CENSUS']
bea_key = keys_dict_2['BEA']

# %%
data = pd.read_csv('../../filtered outputs/PostersExportWideFormat.csv')
data.head()
# Out:
#                 NAME          GEO_ID  Population 2000  Male Under 5 2000  Female Under 5 2000  Male 5 to 14 2000  Female 5 to 14 2000  \
# 0     Stewart County  0500000US47161          12370.0              374.0                353.0              895.0                837.0
# 1  Montgomery County  0500000US47125         134768.0             5901.0               5552.0            11091.0              10213.0
# 2   Robertson County  0500000US47147          54433.0             1897.0               1823.0             4379.0               4046.0
# 3      Sumner County  0500000US47165         130449.0             4567.0               4266.0             9939.0               9347.0
# 4   Trousdale County  0500000US47169           7259.0              217.0                222.0              550.0                467.0
#
#    Male 15 to 24 2000  Female 15 to 24 2000  Male 5 to 9 2000  Female 5 to 9 2000  Male 10 to 14 2000  Female 10 to 14 2000  Male 15 to 17 2000  \
# ...

# %%
df = data[['NAME', 'GEO_ID', 'Population 2010', 'Population 2020', 'Minority % 2020', 'Age%:School Age 5 to 18 2020', 'Poverty%: Below Poverty Level 2020', 
           'Age%:65 and Older 2020', 'Average Household Size 2020', 'Units:Total Series 2010', 'Units:Total Series 2020', 'Units%:1 Unit, Detached 2020', 
           'Units%:1 Unit, Attached 2020', 'Units%:Mobile Home 2020', 'Median Household Income 2020', 'CB%: Cost Burdened Homeowners 2020', 
           'CB%:Cost Burdened Renters 2020', 'Ind:Employed Civilians 16+ 2010', 'Ind:Employed Civilians 16+ 2020', 
           'Ind:Agriculture, Forestry, Fishing and Hunting, and Mining 2020', 'Ind:Construction 2020', 'Ind:Manufacturing 2020', 'Ind:Wholesale Trade 2020', 
           'Ind:Retail Trade 2020', 'Ind:Transportation and Warehousing, Utilities 2020', 'Ind:Information 2020', 
           'Ind:Finance, Insurance, Real Estate and Rental and Leasing 2020', 
           'Ind:Professional, Scientific, Management, Administrative, and Waste Management Services 2020', 'Ind:Educational, Health and Social Services 2020', 
           'Ind:Arts, Entertainment, Recreation, Accommodation and Food Services 2020', 'Ind:Other Services (Except Public Administration) 2020', 
           'Ind:Public Administration 2020', 'Ind%:Blue Collar 2020', 'Ind%:White Collar 2020',
           'Units%:2 2020', 'Units%:3 to 4 2020',
           'Units%:5 to 9 2020', 'Units%:10 to 19 2020', 'Units%:20 to 49 2020', 'Units%:50 or More 2020'
          ]] 
df.head()
# Out:
#                 NAME          GEO_ID  Population 2010  Population 2020  Minority % 2020  Age%:School Age 5 to 18 2020  \
# 0     Stewart County  0500000US47161          13324.0          13657.0         9.782529                     15.531617
# 1  Montgomery County  0500000US47125         172331.0         220069.0        40.339621                     18.449988
# 2   Robertson County  0500000US47147          66283.0          72803.0        21.639218                     17.655180
# 3      Sumner County  0500000US47165         160645.0         196281.0        20.945481                     17.530904
# 4   Trousdale County  0500000US47169           7870.0          11615.0        24.356436                     13.547204
#
#    Poverty%: Below Poverty Level 2020  Age%:65 and Older 2020  Average Household Size 2020  Units:Total Series 2010  Units:Total Series 2020  \
# ...

# %%
df['Percent Increase in Population 2010 to 2020'] = (df['Population 2020'] - df['Population 2010'])*100/df['Population 2010']
df['Percent Increase in Housing Units 2010 to 2020'] = (df['Units:Total Series 2020'] - df['Units:Total Series 2010'])*100/df['Units:Total Series 2010']

totalmonths = 120
diffpeople2010to2020 = df['Population 2020'] - df['Population 2010']
df['People Per Month Between 2010 and 2020'] = diffpeople2010to2020/totalmonths
diffjobs2010to2020 = df['Ind:Employed Civilians 16+ 2020'] - df['Ind:Employed Civilians 16+ 2010']
df['Occupied Jobs Gained Per Month Between 2010 and 2020'] = diffjobs2010to2020/totalmonths
diffjobs2010to2020 = df['Units:Total Series 2020'] - df['Units:Total Series 2010']
df['Housing Units Gained Per Month Between 2010 and 2020'] = diffjobs2010to2020/totalmonths

listpercmultifamily = [df['Units%:2 2020'], df['Units%:3 to 4 2020'], df['Units%:5 to 9 2020'], df['Units%:10 to 19 2020'], df['Units%:20 to 49 2020'], 
                      df['Units%:50 or More 2020']]
df['Housing: Percent Units Multifamily'] = sum(listpercmultifamily)

prof = [df['Ind:Information 2020'], df['Ind:Finance, Insurance, Real Estate and Rental and Leasing 2020'], 
        df['Ind:Professional, Scientific, Management, Administrative, and Waste Management Services 2020'], 
        df['Ind:Educational, Health and Social Services 2020']]
df['Industry ACS: Occupied Employment Professional'] = sum(prof)
df['Industry ACS: Occupied Employment Percent Professional'] = percent(df['Industry ACS: Occupied Employment Professional'], 
                                                                      df['Ind:Employed Civilians 16+ 2020'])
retail = [df['Ind:Retail Trade 2020'], df['Ind:Arts, Entertainment, Recreation, Accommodation and Food Services 2020'], 
          df['Ind:Other Services (Except Public Administration) 2020']]
df['Industry ACS: Occupied Employment Retail'] = sum(retail)
df['Industry ACS: Occupied Employment Percent Retail'] = percent(df['Industry ACS: Occupied Employment Retail'], 
                                                                 df['Ind:Employed Civilians 16+ 2020'])
ind = [df['Ind:Agriculture, Forestry, Fishing and Hunting, and Mining 2020'], df['Ind:Construction 2020'], df['Ind:Manufacturing 2020'], df['Ind:Wholesale Trade 2020'],
       df['Ind:Transportation and Warehousing, Utilities 2020']] 
df['Industry ACS: Occupied Employment Industry'] = sum(ind)
df['Industry ACS: Occupied Employment Percent Industry'] = percent(df['Industry ACS: Occupied Employment Industry'], 
                                                                 df['Ind:Employed Civilians 16+ 2020'])
df['Industry ACS: Occupied Employment Government'] = df['Ind:Public Administration 2020']
df['Industry ACS: Occupied Employment Percent Government'] = percent(df['Industry ACS: Occupied Employment Government'], 
                                                                 df['Ind:Employed Civilians 16+ 2020'])

cols = ['Population 2010', 'Units:Total Series 2010', 'Ind:Employed Civilians 16+ 2010', 'Units%:2 2020', 'Units%:3 to 4 2020',
        'Units%:5 to 9 2020', 'Units%:10 to 19 2020', 'Units%:20 to 49 2020', 'Units%:50 or More 2020',
        'Ind:Agriculture, Forestry, Fishing and Hunting, and Mining 2020', 'Ind:Construction 2020', 'Ind:Manufacturing 2020', 'Ind:Wholesale Trade 2020', 
        'Ind:Retail Trade 2020', 'Ind:Transportation and Warehousing, Utilities 2020', 'Ind:Information 2020', 
        'Ind:Finance, Insurance, Real Estate and Rental and Leasing 2020', 
        'Ind:Professional, Scientific, Management, Administrative, and Waste Management Services 2020', 'Ind:Educational, Health and Social Services 2020', 
        'Ind:Arts, Entertainment, Recreation, Accommodation and Food Services 2020', 'Ind:Other Services (Except Public Administration) 2020', 
        'Ind:Public Administration 2020']
df = df.drop(columns = cols)
# Out:
# C:\Users\jmccall\Anaconda3\envs\geospatial\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df = df.rename(columns = {'Population 2020':'Population: Current Population', 'Minority % 2020':'Population: Ethnic Minorities',
                          'Age%:School Age 5 to 18 2020':'Population: School-Aged Children', 'Poverty%: Below Poverty Level 2020':'Population: Living Below Poverty', 
                          'Age%:65 and Older 2020':'Population: Senior Citizens', 'Average Household Size 2020':'Population: Average Household Size', 
                          'Units:Total Series 2020':'Housing: Current Number of Housing Units', 'Units%:1 Unit, Detached 2020':'Housing: Single Family Detached Homes', 
                          'Units%:1 Unit, Attached 2020':'Housing: Single Family Attached Homes', 'Units%:Mobile Home 2020': 'Housing: Mobile Homes',
                          'Median Household Income 2020':'Housing: Countywide Median Household Income', 
                          'CB%: Cost Burdened Homeowners 2020':'Housing: Percent of Homeowners Who are Costburdened', 
                          'CB%:Cost Burdened Renters 2020':'Housing: Percent of Renters Who are Costburdened', 
                          'Ind:Employed Civilians 16+ 2020':'Employment: Current Number of Occupied Jobs', 
                          'Ind%:Blue Collar 2020':'Industry ACS: Occupied Percent Blue Collar',
                          'Ind%:White Collar 2020':'Industry ACS: Occupied Percent White Collar'
                         })

# %%
df.head()
# Out:
#                 NAME          GEO_ID  Population: Current Population  Population: Ethnic Minorities  Population: School-Aged Children  \
# 0     Stewart County  0500000US47161                         13657.0                       9.782529                         15.531617
# 1  Montgomery County  0500000US47125                        220069.0                      40.339621                         18.449988
# 2   Robertson County  0500000US47147                         72803.0                      21.639218                         17.655180
# 3      Sumner County  0500000US47165                        196281.0                      20.945481                         17.530904
# 4   Trousdale County  0500000US47169                         11615.0                      24.356436                         13.547204
#
#    Population: Living Below Poverty  Population: Senior Citizens  Population: Average Household Size  Housing: Current Number of Housing Units  \
# ...

# %%
def percent(x, y):
    return (x/y)*100

# %%
ind = pd.read_csv('../../data downloads/WoodsandPoole_IndustryEmployment.csv')
ind = ind.set_index(['NAME', 'Description'])
ind = ind.transpose()

# %%
counties = ['Montgomery County', 'Stewart County', 'Houston County', 'Humphreys County', 'Dickson County', 'Cheatham County', 'Robertson County', 'Sumner County',
            'Davidson County', 'Wilson County', 'Trousdale County', 'Williamson County', 'Rutherford County', 'Maury County']

# %%
newstuff = {}
for county in counties:
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Total Jobs')] = ind[('{}'.format(county), 'TOTAL EMPLOYMENT')]
    professional = [ind[('{}'.format(county), 'INFORMATION EMPLOYMENT')], ind[('{}'.format(county), 'FINANCE and INSURANCE EMPLOYMENT')], 
                    ind[('{}'.format(county), 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')],
                    ind[('{}'.format(county), 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')],
                    ind[('{}'.format(county), 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')],
                    ind[('{}'.format(county), 'ADMINISTRATIVE and WASTE SERVICES EMPLOYMENT')], 
                    ind[('{}'.format(county), 'EDUCATIONAL SERVICES EMPLOYMENT')], 
                    ind[('{}'.format(county), 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')]]
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Professional')] = sum(professional)
    newstuff[('{}'.format(county), 'Industry BEA:% Place of Work Professional')] = percent(newstuff[('{}'.format(county), 'Industry BEA:Place of Work Professional')], 
                                                                                                  ind[('{}'.format(county), 'TOTAL EMPLOYMENT')])
    retail = [ind[('{}'.format(county), 'RETAIL TRADE EMPLOYMENT')], ind[('{}'.format(county), 'ARTS, ENTERTAINMENT, and RECREATION EMPLOYMENT')], 
              ind[('{}'.format(county), 'ACCOMMODATION and FOOD SERVICES EMPLOYMENT')], 
              ind[('{}'.format(county), 'OTHER SERVICES, EXCEPT PUBLIC ADMINISTRATION EMPLOYMENT')]]
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Retail')] = sum(retail)
    newstuff[('{}'.format(county), 'Industry BEA:% Place of Work Retail')] = percent(newstuff[('{}'.format(county), 'Industry BEA:Place of Work Retail')], 
                                                                   ind[('{}'.format(county), 'TOTAL EMPLOYMENT')])
    govern = [ind[('{}'.format(county), 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')], 
              ind[('{}'.format(county), 'FEDERAL MILITARY EMPLOYMENT')],  
              ind[('{}'.format(county), 'STATE and LOCAL GOVERNMENT EMPLOYMENT')]]
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Government')] = sum(govern)
    newstuff[('{}'.format(county), 'Industry BEA:% Place of Work Government')] = percent(newstuff[('{}'.format(county), 'Industry BEA:Place of Work Government')], 
                                                                       ind[('{}'.format(county), 'TOTAL EMPLOYMENT')])
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Farm')] = ind[('{}'.format(county), 'FARM EMPLOYMENT')]
    newstuff[('{}'.format(county), 'Industry BEA:% Place of Work Farm')] = percent(newstuff[('{}'.format(county), 'Industry BEA:Place of Work Farm')], 
                                                                 ind[('{}'.format(county), 'TOTAL EMPLOYMENT')])
    indust = [ind[('{}'.format(county), 'FORESTRY, FISHING, RELATED ACTIVITIES and OTHER EMPLOYMENT')], 
              ind[('{}'.format(county), 'MINING EMPLOYMENT')],  
              ind[('{}'.format(county), 'UTILITIES EMPLOYMENT')], 
              ind[('{}'.format(county), 'CONSTRUCTION EMPLOYMENT')],
              ind[('{}'.format(county), 'MANUFACTURING EMPLOYMENT')],
              ind[('{}'.format(county), 'WHOLESALE TRADE EMPLOYMENT')],
              ind[('{}'.format(county), 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')]]
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Industry')] = sum(indust)
    newstuff[('{}'.format(county), 'Industry BEA:% Place of Work Industry')] = percent(newstuff[('{}'.format(county), 'Industry BEA:Place of Work Industry')], 
                                                                     ind[('{}'.format(county), 'TOTAL EMPLOYMENT')])
    blueco = [ind[('{}'.format(county), 'MINING EMPLOYMENT')], 
              ind[('{}'.format(county), 'UTILITIES EMPLOYMENT')],  
              ind[('{}'.format(county), 'CONSTRUCTION EMPLOYMENT')], 
              ind[('{}'.format(county), 'MANUFACTURING EMPLOYMENT')],
              ind[('{}'.format(county), 'WHOLESALE TRADE EMPLOYMENT')],
              ind[('{}'.format(county), 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')]]
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Blue Collar')] = sum(blueco)
    newstuff[('{}'.format(county), 'Industry BEA:% Place of Work Blue Collar')] = percent(sum(blueco), ind[('{}'.format(county), 'TOTAL EMPLOYMENT')])
    whitec = [ind[('{}'.format(county), 'INFORMATION EMPLOYMENT')], 
              ind[('{}'.format(county), 'FINANCE and INSURANCE EMPLOYMENT')],  
              ind[('{}'.format(county), 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], 
              ind[('{}'.format(county), 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')],
              ind[('{}'.format(county), 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')],
              ind[('{}'.format(county), 'EDUCATIONAL SERVICES EMPLOYMENT')],
              ind[('{}'.format(county), 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')],
              ind[('{}'.format(county), 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')]]
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work White Collar')] = sum(whitec)
    newstuff[('{}'.format(county), 'Industry BEA:% Place of Work White Collar')] = percent(sum(whitec), ind[('{}'.format(county), 'TOTAL EMPLOYMENT')])
    newstuff[('{}'.format(county), 'Industry BEA:Place of Work Total Jobs 2010')] = ind[('{}'.format(county), 'TOTAL EMPLOYMENT 2010')]
    changetotaljobs = ind[('{}'.format(county), 'TOTAL EMPLOYMENT')] - ind[('{}'.format(county), 'TOTAL EMPLOYMENT 2010')]
    newstuff[('{}'.format(county), 'Industry BEA:% Change in Total Jobs Since 2010')] = changetotaljobs*100/ind[('{}'.format(county), 'TOTAL EMPLOYMENT 2010')]
    newstuff[('{}'.format(county), 'Industry BEA:Jobs Gained Per Month Since 2010')] = changetotaljobs/totalmonths
    newdata = pd.concat(newstuff, axis = 1)

# %%
#regions
#total gnrc
gnrctotaljobsinli = [newdata[('Cheatham County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Davidson County', 'Industry BEA:Place of Work Total Jobs')],
                     newdata[('Dickson County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Houston County', 'Industry BEA:Place of Work Total Jobs')],
                     newdata[('Humphreys County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Montgomery County', 'Industry BEA:Place of Work Total Jobs')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Rutherford County', 'Industry BEA:Place of Work Total Jobs')], 
                     newdata[('Stewart County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Sumner County', 'Industry BEA:Place of Work Total Jobs')], 
                     newdata[('Trousdale County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Williamson County', 'Industry BEA:Place of Work Total Jobs')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Total Jobs')]]
gnrctotal2020var = sum(gnrctotaljobsinli)
newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')] = sum(gnrctotaljobsinli)
gnrctotaljobs2010 =  [ind[('Cheatham County', 'TOTAL EMPLOYMENT 2010')], ind[('Davidson County', 'TOTAL EMPLOYMENT 2010')],
                     ind[('Dickson County', 'TOTAL EMPLOYMENT 2010')], ind[('Houston County', 'TOTAL EMPLOYMENT 2010')],
                     ind[('Humphreys County', 'TOTAL EMPLOYMENT 2010')], ind[('Montgomery County', 'TOTAL EMPLOYMENT 2010')], 
                     ind[('Robertson County', 'TOTAL EMPLOYMENT 2010')], ind[('Rutherford County', 'TOTAL EMPLOYMENT 2010')], 
                     ind[('Stewart County', 'TOTAL EMPLOYMENT 2010')], ind[('Sumner County', 'TOTAL EMPLOYMENT 2010')], 
                     ind[('Trousdale County', 'TOTAL EMPLOYMENT 2010')], ind[('Williamson County', 'TOTAL EMPLOYMENT 2010')],
                     ind[('Wilson County', 'TOTAL EMPLOYMENT 2010')]]
gnrctotal2010var = sum(gnrctotaljobs2010)
newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs 2010')] = sum(gnrctotaljobs2010)
#professional gnrc
gnrcprofessional =  [newdata[('Cheatham County', 'Industry BEA:Place of Work Professional')], newdata[('Davidson County', 'Industry BEA:Place of Work Professional')],
                     newdata[('Dickson County', 'Industry BEA:Place of Work Professional')], newdata[('Houston County', 'Industry BEA:Place of Work Professional')],
                     newdata[('Humphreys County', 'Industry BEA:Place of Work Professional')], newdata[('Montgomery County', 'Industry BEA:Place of Work Professional')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Professional')], newdata[('Rutherford County', 'Industry BEA:Place of Work Professional')], 
                     newdata[('Stewart County', 'Industry BEA:Place of Work Professional')], newdata[('Sumner County', 'Industry BEA:Place of Work Professional')], 
                     newdata[('Trousdale County', 'Industry BEA:Place of Work Professional')], newdata[('Williamson County', 'Industry BEA:Place of Work Professional')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Professional')]]
newdata[('GNRC', 'Industry BEA:Place of Work Professional')] = sum(gnrcprofessional)
newdata[('GNRC', 'Industry BEA:% Place of Work Professional')] = percent(newdata[('GNRC', 'Industry BEA:Place of Work Professional')], 
                                                                         newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')])
#retail
gnrcretailjobsin =  [newdata[('Cheatham County', 'Industry BEA:Place of Work Retail')], newdata[('Davidson County', 'Industry BEA:Place of Work Retail')],
                     newdata[('Dickson County', 'Industry BEA:Place of Work Retail')], newdata[('Houston County', 'Industry BEA:Place of Work Retail')],
                     newdata[('Humphreys County', 'Industry BEA:Place of Work Retail')], newdata[('Montgomery County', 'Industry BEA:Place of Work Retail')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Retail')], newdata[('Rutherford County', 'Industry BEA:Place of Work Retail')], 
                     newdata[('Stewart County', 'Industry BEA:Place of Work Retail')], newdata[('Sumner County', 'Industry BEA:Place of Work Retail')], 
                     newdata[('Trousdale County', 'Industry BEA:Place of Work Retail')], newdata[('Williamson County', 'Industry BEA:Place of Work Retail')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Retail')]]
newdata[('GNRC', 'Industry BEA:Place of Work Retail')] = sum(gnrcretailjobsin)
newdata[('GNRC', 'Industry BEA:% Place of Work Retail')] = percent(newdata[('GNRC', 'Industry BEA:Place of Work Retail')], 
                                                               newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')])
#government
gnrcgovernmentjob =  [newdata[('Cheatham County', 'Industry BEA:Place of Work Government')], newdata[('Davidson County', 'Industry BEA:Place of Work Government')],
                     newdata[('Dickson County', 'Industry BEA:Place of Work Government')], newdata[('Houston County', 'Industry BEA:Place of Work Government')],
                     newdata[('Humphreys County', 'Industry BEA:Place of Work Government')], newdata[('Montgomery County', 'Industry BEA:Place of Work Government')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Government')], newdata[('Rutherford County', 'Industry BEA:Place of Work Government')], 
                     newdata[('Stewart County', 'Industry BEA:Place of Work Government')], newdata[('Sumner County', 'Industry BEA:Place of Work Government')], 
                     newdata[('Trousdale County', 'Industry BEA:Place of Work Government')], newdata[('Williamson County', 'Industry BEA:Place of Work Government')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Government')]]
newdata[('GNRC', 'Industry BEA:Place of Work Government')] = sum(gnrcgovernmentjob)
newdata[('GNRC', 'Industry BEA:% Place of Work Government')] = percent(newdata[('GNRC', 'Industry BEA:Place of Work Government')], 
                                                               newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')])
#farm
gnrcgovernmentjob =  [newdata[('Cheatham County', 'Industry BEA:Place of Work Farm')], newdata[('Davidson County', 'Industry BEA:Place of Work Farm')],
                     newdata[('Dickson County', 'Industry BEA:Place of Work Farm')], newdata[('Houston County', 'Industry BEA:Place of Work Farm')],
                     newdata[('Humphreys County', 'Industry BEA:Place of Work Farm')], newdata[('Montgomery County', 'Industry BEA:Place of Work Farm')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Farm')], newdata[('Rutherford County', 'Industry BEA:Place of Work Farm')], 
                     newdata[('Stewart County', 'Industry BEA:Place of Work Farm')], newdata[('Sumner County', 'Industry BEA:Place of Work Farm')], 
                     newdata[('Trousdale County', 'Industry BEA:Place of Work Farm')], newdata[('Williamson County', 'Industry BEA:Place of Work Farm')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Farm')]]
newdata[('GNRC', 'Industry BEA:Place of Work Farm')] = sum(gnrcgovernmentjob)
newdata[('GNRC', 'Industry BEA:% Place of Work Farm')] = percent(newdata[('GNRC', 'Industry BEA:Place of Work Farm')], 
                                                               newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')])
#industry
gnrcindustryijob =  [newdata[('Cheatham County', 'Industry BEA:Place of Work Industry')], newdata[('Davidson County', 'Industry BEA:Place of Work Industry')],
                     newdata[('Dickson County', 'Industry BEA:Place of Work Industry')], newdata[('Houston County', 'Industry BEA:Place of Work Industry')],
                     newdata[('Humphreys County', 'Industry BEA:Place of Work Industry')], newdata[('Montgomery County', 'Industry BEA:Place of Work Industry')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Industry')], newdata[('Rutherford County', 'Industry BEA:Place of Work Industry')], 
                     newdata[('Stewart County', 'Industry BEA:Place of Work Industry')], newdata[('Sumner County', 'Industry BEA:Place of Work Industry')], 
                     newdata[('Trousdale County', 'Industry BEA:Place of Work Industry')], newdata[('Williamson County', 'Industry BEA:Place of Work Industry')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Industry')]]
newdata[('GNRC', 'Industry BEA:Place of Work Industry')] = sum(gnrcindustryijob)
newdata[('GNRC', 'Industry BEA:% Place of Work Industry')] = percent(newdata[('GNRC', 'Industry BEA:Place of Work Industry')], 
                                                               newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')])
#blue collar
gnrcbluecollarjo =  [ind[('Cheatham County', 'MINING EMPLOYMENT')], ind[('Cheatham County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Cheatham County', 'CONSTRUCTION EMPLOYMENT')], ind[('Cheatham County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Cheatham County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Cheatham County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Davidson County', 'MINING EMPLOYMENT')], ind[('Davidson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Davidson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Davidson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Davidson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Davidson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Dickson County', 'MINING EMPLOYMENT')], ind[('Dickson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Dickson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Dickson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Dickson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Dickson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Houston County', 'MINING EMPLOYMENT')], ind[('Houston County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Houston County', 'CONSTRUCTION EMPLOYMENT')], ind[('Houston County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Houston County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Houston County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Humphreys County', 'MINING EMPLOYMENT')], ind[('Humphreys County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Humphreys County', 'CONSTRUCTION EMPLOYMENT')], ind[('Humphreys County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Humphreys County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Humphreys County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Montgomery County', 'MINING EMPLOYMENT')], ind[('Montgomery County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Montgomery County', 'CONSTRUCTION EMPLOYMENT')], ind[('Montgomery County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Montgomery County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Montgomery County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Robertson County', 'MINING EMPLOYMENT')], ind[('Robertson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Robertson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Robertson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Robertson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Robertson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Rutherford County', 'MINING EMPLOYMENT')], ind[('Rutherford County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Rutherford County', 'CONSTRUCTION EMPLOYMENT')], ind[('Rutherford County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Rutherford County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Rutherford County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Stewart County', 'MINING EMPLOYMENT')], ind[('Stewart County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Stewart County', 'CONSTRUCTION EMPLOYMENT')], ind[('Stewart County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Stewart County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Stewart County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Sumner County', 'MINING EMPLOYMENT')], ind[('Sumner County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Sumner County', 'CONSTRUCTION EMPLOYMENT')], ind[('Sumner County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Sumner County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Sumner County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Trousdale County', 'MINING EMPLOYMENT')], ind[('Trousdale County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Trousdale County', 'CONSTRUCTION EMPLOYMENT')], ind[('Trousdale County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Trousdale County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Trousdale County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Williamson County', 'MINING EMPLOYMENT')], ind[('Williamson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Williamson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Williamson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Williamson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Williamson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Wilson County', 'MINING EMPLOYMENT')], ind[('Wilson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Wilson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Wilson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Wilson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Wilson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')]]
newdata[('GNRC', 'Industry BEA:Place of Work Blue Collar')] = sum(gnrcbluecollarjo)
newdata[('GNRC', 'Industry BEA:% Place of Work Blue Collar')] = percent(newdata[('GNRC', 'Industry BEA:Place of Work Blue Collar')], 
                                                               newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')])
#blue collar
gnrcwhitecollarj =  [ind[('Cheatham County', 'INFORMATION EMPLOYMENT')], ind[('Cheatham County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Cheatham County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Cheatham County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Cheatham County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Cheatham County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Cheatham County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Cheatham County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Davidson County', 'INFORMATION EMPLOYMENT')], ind[('Davidson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Davidson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Davidson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Davidson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Davidson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Davidson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Davidson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Dickson County', 'INFORMATION EMPLOYMENT')], ind[('Dickson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Dickson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Dickson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Dickson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Dickson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Dickson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Dickson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Houston County', 'INFORMATION EMPLOYMENT')], ind[('Houston County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Houston County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Houston County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Houston County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Houston County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Houston County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Houston County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Humphreys County', 'INFORMATION EMPLOYMENT')], ind[('Humphreys County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Humphreys County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Humphreys County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Humphreys County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Humphreys County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Humphreys County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Humphreys County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Montgomery County', 'INFORMATION EMPLOYMENT')], ind[('Montgomery County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Montgomery County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Montgomery County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Montgomery County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Montgomery County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Montgomery County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Montgomery County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Robertson County', 'INFORMATION EMPLOYMENT')], ind[('Robertson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Robertson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Robertson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Robertson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Robertson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Robertson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Robertson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Rutherford County', 'INFORMATION EMPLOYMENT')], ind[('Rutherford County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Rutherford County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Rutherford County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Rutherford County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Rutherford County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Rutherford County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Rutherford County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Stewart County', 'INFORMATION EMPLOYMENT')], ind[('Stewart County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Stewart County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Stewart County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Stewart County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Stewart County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Stewart County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Stewart County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Sumner County', 'INFORMATION EMPLOYMENT')], ind[('Sumner County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Sumner County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Sumner County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Sumner County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Sumner County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Sumner County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Sumner County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Trousdale County', 'INFORMATION EMPLOYMENT')], ind[('Trousdale County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Trousdale County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Trousdale County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Trousdale County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Trousdale County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Trousdale County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Trousdale County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Williamson County', 'INFORMATION EMPLOYMENT')], ind[('Williamson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Williamson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Williamson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Williamson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Williamson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Williamson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Williamson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Wilson County', 'INFORMATION EMPLOYMENT')], ind[('Wilson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Wilson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Wilson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Wilson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Wilson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Wilson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Wilson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')]]
newdata[('GNRC', 'Industry BEA:Place of Work White Collar')] = sum(gnrcwhitecollarj)
newdata[('GNRC', 'Industry BEA:% Place of Work White Collar')] = percent(newdata[('GNRC', 'Industry BEA:Place of Work White Collar')], 
                                                               newdata[('GNRC', 'Industry BEA:Place of Work Total Jobs')])
gnrcchangetotaljobs = gnrctotal2020var - gnrctotal2010var
newdata[('GNRC', 'Industry BEA:% Change in Total Jobs Since 2010')] = gnrcchangetotaljobs*100/gnrctotal2010var
newdata[('GNRC', 'Industry BEA:Jobs Gained Per Month Since 2010')] = gnrcchangetotaljobs/totalmonths

# %%
#regions
#total mpo
mpototaljobsinli = [newdata[('Davidson County', 'Industry BEA:Place of Work Total Jobs')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Rutherford County', 'Industry BEA:Place of Work Total Jobs')], 
                     newdata[('Sumner County', 'Industry BEA:Place of Work Total Jobs')], 
                     newdata[('Maury County', 'Industry BEA:Place of Work Total Jobs')], newdata[('Williamson County', 'Industry BEA:Place of Work Total Jobs')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Total Jobs')]]
mpototal2020var = sum(mpototaljobsinli)
newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')] = sum(gnrctotaljobsinli)
mpototaljobs2010 =  [ind[('Davidson County', 'TOTAL EMPLOYMENT 2010')], 
                     ind[('Robertson County', 'TOTAL EMPLOYMENT 2010')], ind[('Rutherford County', 'TOTAL EMPLOYMENT 2010')], 
                     ind[('Sumner County', 'TOTAL EMPLOYMENT 2010')], 
                     ind[('Maury County', 'TOTAL EMPLOYMENT 2010')], ind[('Williamson County', 'TOTAL EMPLOYMENT 2010')],
                     ind[('Wilson County', 'TOTAL EMPLOYMENT 2010')]]
mpototal2010var = sum(mpototaljobs2010)
newdata[('MPO', 'Industry BEA:Place of Work Total Jobs 2010')] = sum(mpototaljobs2010)
#professional gnrc
mpoprofessional =  [newdata[('Davidson County', 'Industry BEA:Place of Work Professional')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Professional')], newdata[('Rutherford County', 'Industry BEA:Place of Work Professional')], 
                     newdata[('Sumner County', 'Industry BEA:Place of Work Professional')], 
                     newdata[('Maury County', 'Industry BEA:Place of Work Professional')], newdata[('Williamson County', 'Industry BEA:Place of Work Professional')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Professional')]]
newdata[('MPO', 'Industry BEA:Place of Work Professional')] = sum(mpoprofessional)
newdata[('MPO', 'Industry BEA:% Place of Work Professional')] = percent(newdata[('MPO', 'Industry BEA:Place of Work Professional')], 
                                                                         newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')])
#retail
mporetailjobsin =  [newdata[('Davidson County', 'Industry BEA:Place of Work Retail')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Retail')], newdata[('Rutherford County', 'Industry BEA:Place of Work Retail')], 
                     newdata[('Sumner County', 'Industry BEA:Place of Work Retail')], 
                     newdata[('Maury County', 'Industry BEA:Place of Work Retail')], newdata[('Williamson County', 'Industry BEA:Place of Work Retail')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Retail')]]
newdata[('MPO', 'Industry BEA:Place of Work Retail')] = sum(mporetailjobsin)
newdata[('MPO', 'Industry BEA:% Place of Work Retail')] = percent(newdata[('MPO', 'Industry BEA:Place of Work Retail')], 
                                                               newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')])
#government
mpogovernmentjob =  [newdata[('Davidson County', 'Industry BEA:Place of Work Government')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Government')], newdata[('Rutherford County', 'Industry BEA:Place of Work Government')], 
                     newdata[('Sumner County', 'Industry BEA:Place of Work Government')], 
                     newdata[('Maury County', 'Industry BEA:Place of Work Government')], newdata[('Williamson County', 'Industry BEA:Place of Work Government')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Government')]]
newdata[('MPO', 'Industry BEA:Place of Work Government')] = sum(mpogovernmentjob)
newdata[('MPO', 'Industry BEA:% Place of Work Government')] = percent(newdata[('MPO', 'Industry BEA:Place of Work Government')], 
                                                               newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')])
#farm
mpogovernmentjob =  [newdata[('Davidson County', 'Industry BEA:Place of Work Farm')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Farm')], newdata[('Rutherford County', 'Industry BEA:Place of Work Farm')], 
                     newdata[('Sumner County', 'Industry BEA:Place of Work Farm')], 
                     newdata[('Maury County', 'Industry BEA:Place of Work Farm')], newdata[('Williamson County', 'Industry BEA:Place of Work Farm')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Farm')]]
newdata[('MPO', 'Industry BEA:Place of Work Farm')] = sum(mpogovernmentjob)
newdata[('MPO', 'Industry BEA:% Place of Work Farm')] = percent(newdata[('MPO', 'Industry BEA:Place of Work Farm')], 
                                                               newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')])
#industry
mpoindustryijob =  [newdata[('Davidson County', 'Industry BEA:Place of Work Industry')], 
                     newdata[('Robertson County', 'Industry BEA:Place of Work Industry')], newdata[('Rutherford County', 'Industry BEA:Place of Work Industry')], 
                     newdata[('Sumner County', 'Industry BEA:Place of Work Industry')], 
                     newdata[('Maury County', 'Industry BEA:Place of Work Industry')], newdata[('Williamson County', 'Industry BEA:Place of Work Industry')],
                     newdata[('Wilson County', 'Industry BEA:Place of Work Industry')]]
newdata[('MPO', 'Industry BEA:Place of Work Industry')] = sum(mpoindustryijob)
newdata[('MPO', 'Industry BEA:% Place of Work Industry')] = percent(newdata[('MPO', 'Industry BEA:Place of Work Industry')], 
                                                               newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')])
#blue collar
mpobluecollarjo =  [ind[('Davidson County', 'MINING EMPLOYMENT')], ind[('Davidson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Davidson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Davidson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Davidson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Davidson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Robertson County', 'MINING EMPLOYMENT')], ind[('Robertson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Robertson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Robertson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Robertson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Robertson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Rutherford County', 'MINING EMPLOYMENT')], ind[('Rutherford County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Rutherford County', 'CONSTRUCTION EMPLOYMENT')], ind[('Rutherford County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Rutherford County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Rutherford County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Sumner County', 'MINING EMPLOYMENT')], ind[('Sumner County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Sumner County', 'CONSTRUCTION EMPLOYMENT')], ind[('Sumner County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Sumner County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Sumner County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Maury County', 'MINING EMPLOYMENT')], ind[('Trousdale County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Maury County', 'CONSTRUCTION EMPLOYMENT')], ind[('Trousdale County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Maury County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Trousdale County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Williamson County', 'MINING EMPLOYMENT')], ind[('Williamson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Williamson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Williamson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Williamson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Williamson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')],
                     ind[('Wilson County', 'MINING EMPLOYMENT')], ind[('Wilson County', 'UTILITIES EMPLOYMENT')], 
                     ind[('Wilson County', 'CONSTRUCTION EMPLOYMENT')], ind[('Wilson County', 'MANUFACTURING EMPLOYMENT')], 
                     ind[('Wilson County', 'WHOLESALE TRADE EMPLOYMENT')], ind[('Wilson County', 'TRANSPORTATION and WAREHOUSING EMPLOYMENT')]]
newdata[('MPO', 'Industry BEA:Place of Work Blue Collar')] = sum(mpobluecollarjo)
newdata[('MPO', 'Industry BEA:% Place of Work Blue Collar')] = percent(newdata[('MPO', 'Industry BEA:Place of Work Blue Collar')], 
                                                               newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')])
#blue collar
mpowhitecollarj =  [ind[('Davidson County', 'INFORMATION EMPLOYMENT')], ind[('Davidson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Davidson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Davidson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Davidson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Davidson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Davidson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Davidson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Robertson County', 'INFORMATION EMPLOYMENT')], ind[('Robertson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Robertson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Robertson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Robertson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Robertson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Robertson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Robertson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Rutherford County', 'INFORMATION EMPLOYMENT')], ind[('Rutherford County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Rutherford County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Rutherford County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Rutherford County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Rutherford County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Rutherford County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Rutherford County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Sumner County', 'INFORMATION EMPLOYMENT')], ind[('Sumner County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Sumner County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Sumner County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Sumner County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Sumner County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Sumner County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Sumner County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Maury County', 'INFORMATION EMPLOYMENT')], ind[('Trousdale County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Maury County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Trousdale County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Maury County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Trousdale County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Maury County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Trousdale County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Williamson County', 'INFORMATION EMPLOYMENT')], ind[('Williamson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Williamson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Williamson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Williamson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Williamson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Williamson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Williamson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')],
                     ind[('Wilson County', 'INFORMATION EMPLOYMENT')], ind[('Wilson County', 'FINANCE and INSURANCE EMPLOYMENT')], 
                     ind[('Wilson County', 'REAL ESTATE and RENTAL and LEASE EMPLOYMENT')], ind[('Wilson County', 'PROFESSIONAL and TECHNICAL SERVICES EMPLOYMENT')], 
                     ind[('Wilson County', 'MANAGEMENT of COMPANIES and ENTERPRISES EMPLOYMENT')], ind[('Wilson County', 'EDUCATIONAL SERVICES EMPLOYMENT')],
                     ind[('Wilson County', 'HEALTH CARE and SOCIAL ASSISTANCE EMPLOYMENT')], ind[('Wilson County', 'FEDERAL CIVILIAN GOVERNMENT EMPLOYMENT')]]
newdata[('MPO', 'Industry BEA:Place of Work White Collar')] = sum(mpowhitecollarj)
newdata[('MPO', 'Industry BEA:% Place of Work White Collar')] = percent(newdata[('MPO', 'Industry BEA:Place of Work White Collar')], 
                                                               newdata[('MPO', 'Industry BEA:Place of Work Total Jobs')])
mpochangetotaljobs = mpototal2020var - mpototal2010var
newdata[('MPO', 'Industry BEA:% Change in Total Jobs Since 2010')] = mpochangetotaljobs*100/mpototal2010var
newdata[('MPO', 'Industry BEA:Jobs Gained Per Month Since 2010')] = mpochangetotaljobs/totalmonths

# %%
data = newdata
data = data.stack(0, 1).reset_index()
data = data.drop(columns = 'level_0').rename(columns = {'level_1':'NAME'})

# %%
data.tail(20)
# Out:
#                  NAME  Industry BEA:% Change in Total Jobs Since 2010  Industry BEA:% Place of Work Blue Collar  Industry BEA:% Place of Work Farm  \
# 0     Cheatham County                                        9.024756                                 35.813375                           2.813768
# 1     Davidson County                                       24.229596                                 19.175594                           0.069902
# 2      Dickson County                                       19.836487                                 28.213325                           4.377997
# 3                GNRC                                       30.475592                                 21.918615                           0.866877
# 4      Houston County                                       -9.197787                                 18.926123                          12.909368
# ...

# %%
final = df.merge(data, on = 'NAME')

# %%
final.head()
# Out:
#                 NAME          GEO_ID  Population: Current Population  Population: Ethnic Minorities  Population: School-Aged Children  \
# 0     Stewart County  0500000US47161                         13657.0                       9.782529                         15.531617
# 1  Montgomery County  0500000US47125                        220069.0                      40.339621                         18.449988
# 2   Robertson County  0500000US47147                         72803.0                      21.639218                         17.655180
# 3      Sumner County  0500000US47165                        196281.0                      20.945481                         17.530904
# 4   Trousdale County  0500000US47169                         11615.0                      24.356436                         13.547204
#
#    Population: Living Below Poverty  Population: Senior Citizens  Population: Average Household Size  Housing: Current Number of Housing Units  \
# ...

# %% [markdown]
# # Averages and Medians
# + Average Household Size
# + ,34980
# + 1871903

# %%
url_str= 'https://api.census.gov/data/2020/acs/acs5?key='+census_key
predicates= {}
get_vars= ["NAME", "GEO_ID", 'B25010_001E', 'B19013_001E']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "metropolitan statistical area/micropolitan statistical area: 34980, 17300"
data= requests.get(url_str, params= predicates)
col_names = ['NAME', 'GEO_ID','Population: Average Household Size', 'Housing: Median Household Income', 'FIPS']
avgs=pd.DataFrame(columns=col_names, data=data.json()[1:])
avgs = avgs.drop(columns = 'FIPS')
avgs.head()
# Out:
#                                                 NAME          GEO_ID Population: Average Household Size Housing: Median Household Income
# 0                      Clarksville, TN-KY Metro Area  310M600US17300                               2.63                            54911
# 1  Nashville-Davidson--Murfreesboro--Franklin, TN...  310M600US34980                               2.57                            68406

# %%
newfinal = final.append(avgs).reset_index(drop = True)

# %%
newfinal.head(30)
# Out:
#                                                  NAME          GEO_ID  Population: Current Population  Population: Ethnic Minorities  \
# 0                                      Stewart County  0500000US47161                         13657.0                       9.782529
# 1                                   Montgomery County  0500000US47125                        220069.0                      40.339621
# 2                                    Robertson County  0500000US47147                         72803.0                      21.639218
# 3                                       Sumner County  0500000US47165                        196281.0                      20.945481
# 4                                    Trousdale County  0500000US47169                         11615.0                      24.356436
# 5                                      Houston County  0500000US47083                          8283.0                       9.561753
# ...

# %%
newfinal.to_csv('AtaGlancePosters.csv', index = False)
